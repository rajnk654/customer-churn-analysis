# %%
# To load a CSV file using pandas in Python
import pandas as pd
df = pd.read_csv("../Customer_telco_churn.csv")

# %%
#Displaying random sample of 10 rows from the DataFrame
#sample method is used to return a random number of rows from the dataframe
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2759  1194-SPVSP    Male              0      No         No       1
# 2515  8869-LIHMK  Female              0      No         No      64
# 3000  7613-LLQFO    Male              0      No         No      12
# 6092  4024-CSNBY  Female              0     Yes         No      72
# 4509  2013-SGDXK  Female              0      No         No       1
# 6650  5850-BDWCY  Female              0      No         No       6
# 4970  9795-VOWON    Male              0      No         No       7
# 6813  0617-AQNWT  Female              0     Yes         No      64
# 3435  4450-DLLMH    Male              0      No         No       2
# 4496  9489-JMTTN  Female              0     Yes        Yes      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2759          Yes                No              No  No internet service  ...
# ...

# %%
# To check how many datatypes are present in each column of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#Drop unnecessary columns
#Dropping columns 'customerID' and 'Unnamed: 0' as they are not needed for analysis
df = df.drop(columns=['customerID'])

# %%
# To verify that the columns have been dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
# Analyze categorical features by printing the count of unique values,
# which helps in selecting appropriate encoding techniques.

numerical_features_list = ['tenure', 'MonthlyCharges', 'TotalCharges']
for col in df.columns:
    if col not in numerical_features_list:
        print(col, ":", df[col].nunique())
        print("-" * 50)
# Out:
# gender : 2
# --------------------------------------------------
# SeniorCitizen : 2
# --------------------------------------------------
# Partner : 2
# --------------------------------------------------
# Dependents : 2
# --------------------------------------------------
# PhoneService : 2
# --------------------------------------------------
# MultipleLines : 3
# --------------------------------------------------
# InternetService : 3
# --------------------------------------------------
# OnlineSecurity : 3
# --------------------------------------------------
# OnlineBackup : 3
# --------------------------------------------------
# DeviceProtection : 3
# --------------------------------------------------
# TechSupport : 3
# --------------------------------------------------
# StreamingTV : 3
# --------------------------------------------------
# StreamingMovies : 3
# --------------------------------------------------
# Contract : 3
# ...

# %%
#we see that TotalCharges has some issues because it should be numerical but has some non-numeric values. 
# So we need to convert it to numeric.
# First, we can replace the spaces with NaN or 0.0

df[df['TotalCharges']==" "]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
# So we need to convert it to numeric.
df['TotalCharges']=df['TotalCharges'].replace(" ",0.0)

# %%
#we see that TotalCharges has some issues because it should be numerical but has some non-numeric values. 
# So we need to convert it to numeric.
df['TotalCharges']=df['TotalCharges'].astype(float)

# %%
#To verify the changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
# Identifying columns with categorical data type
object_columns = df.select_dtypes(include=['object']).columns
print(object_columns)
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
#Applying label encoding to binary categorical features
#We converting all categorical features with two unique values to numerical format using label encoding.
#Because many machine learning algorithms require numerical input.

#We are not using one-hot encoding here because it can lead to the "curse of dimensionality(Means dimensionality of the dataframe goes up very high)"
# when applied to features with many unique values.Therefore,label encoding is more efficient for binary categorical features.
from sklearn.preprocessing import LabelEncoder


#Initialize a dictionary to save label encoders for each binary feature
encoders ={}

#Apply label encoding store the encoders
for column in object_columns:
    label_encoders = LabelEncoder()
    df[column] = label_encoders.fit_transform(df[column])
    encoders[column] = label_encoders

# %%
encoders
# Out:
# {'gender': LabelEncoder(),
#  'Partner': LabelEncoder(),
#  'Dependents': LabelEncoder(),
#  'PhoneService': LabelEncoder(),
#  'MultipleLines': LabelEncoder(),
#  'InternetService': LabelEncoder(),
#  'OnlineSecurity': LabelEncoder(),
#  'OnlineBackup': LabelEncoder(),
#  'DeviceProtection': LabelEncoder(),
#  'TechSupport': LabelEncoder(),
#  'StreamingTV': LabelEncoder(),
#  'StreamingMovies': LabelEncoder(),
#  'Contract': LabelEncoder(),
#  'PaperlessBilling': LabelEncoder(),
#  'PaymentMethod': LabelEncoder(),
#  'Churn': LabelEncoder()}

# %%
# To check the dataframe after label encoding
df.head(20)
# Out:
#     gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0        0              0        1           0       1             0
# 1        1              0        0           0      34             1
# 2        1              0        0           0       2             1
# 3        1              0        0           0      45             0
# 4        0              0        0           0       2             1
# 5        0              0        0           0       8             1
# 6        1              0        0           1      22             1
# 7        0              0        0           0      10             0
# 8        0              0        1           0      28             1
# 9        1              0        0           1      62             1
# 10       1              0        1           1      13             1
# 11       1              0        0           0      16             1
# 12       1              0        1           0      58             1
# ...

# %%
#Seperating features and target variable
X = df.drop('Churn', axis=1)
y = df['Churn']

# %%
print(X.shape)
# Out:
# (7043, 19)

# %%
#  the columns to be scaled

col_to_scale =['tenure','MonthlyCharges','TotalCharges']
df_numeric  = df[col_to_scale]

# %%
#Applying Normalization scaling
#Importing Normalizer from sklearn.preprocessing
from sklearn.preprocessing import Normalizer

#Creating an instance of Normalizer
normalizer = Normalizer()
#Fitting and transforming the numeric DataFrame
df_normalized = pd.DataFrame(normalizer.fit_transform(df_numeric), columns=col_to_scale)
#Displaying the first 10 rows of the normalized DataFrame
print("Normalized DataFrame:", df_normalized.head())
# Out:
# Normalized DataFrame:      tenure  MonthlyCharges  TotalCharges
# 0  0.023682        0.706908      0.706908
# 1  0.017983        0.030122      0.999384
# 2  0.016552        0.445662      0.895048
# 3  0.024433        0.022967      0.999438
# 4  0.011952        0.422512      0.906279

# %%
# Import necessary libraries for model training and evaluation
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Train-Test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# Decision Tree model
dt_model = DecisionTreeClassifier(
    max_depth=5,
    random_state=42
)

# Train the model
dt_model.fit(X_train, y_train)

# Predictions
y_pred = dt_model.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7865593942262187
# Confusion Matrix:
#  [[1331  221]
#  [ 230  331]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86      1552
#            1       0.60      0.59      0.59       561
#
#     accuracy                           0.79      2113
#    macro avg       0.73      0.72      0.72      2113
# weighted avg       0.79      0.79      0.79      2113
